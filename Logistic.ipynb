# %%
import os 
import numpy as np
import pandas as pd
#import matplotlib.plyplot as plt
import matplotlib.pyplot as plt

# %%
os.chdir("C:\\Users\\DELL\\Desktop\\Statistics_ML\\Linear & Logistic In SAS_2\\Python - Linear n Logistic")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Desktop\\Statistics_ML\\Linear & Logistic In SAS_2\\Python - Linear n Logistic'

# %%
df=pd.read_sas("bankloan.sas7bdat", encoding='iso-8859-1')

# %%
df.to_csv("Data.csv", index=False)

# %%
df.default.value_counts()
# Out:
# 0.0    517
# 1.0    183
# Name: default, dtype: int64

# %%
df["default"].isnull().sum() # count of missing where there is no
# Out:
# 150

# %%
df_new_customer=df[df.default.isnull()]

# %%
df_new_customer.shape
# Out:
# (150, 9)

# %%
df_new_customer
# Out:
#       age   ed  employ  address  income  debtinc   creddebt    othdebt  \
# 700  36.0  1.0    16.0     13.0    32.0     10.9   0.544128   2.943872
# 701  50.0  1.0     6.0     27.0    21.0     12.9   1.316574   1.392426
# 702  40.0  1.0     9.0      9.0    33.0     17.0   4.880700   0.729300
# 703  31.0  1.0     5.0      7.0    23.0      2.0   0.046000   0.414000
# 704  29.0  1.0     4.0      0.0    24.0      7.8   0.866736   1.005264
# 705  25.0  2.0     1.0      3.0    14.0      9.9   0.232848   1.153152
# 706  34.0  1.0     4.0      3.0    28.0      9.4   1.058064   1.573936
# 707  50.0  1.0    30.0      8.0   150.0     32.5  13.552500  35.197500
# 708  27.0  1.0     5.0      5.0    26.0      1.2   0.130416   0.181584
# 709  31.0  4.0     7.0     12.0    97.0      6.0   1.827480   3.992520
# 710  45.0  1.0     8.0     25.0    27.0      2.6   0.415584   0.286416
# 711  35.0  1.0    10.0      8.0    28.0      1.3   0.109928   0.254072
# 712  47.0  2.0    27.0      7.0   107.0      6.1   1.638277   4.888723
# 713  50.0  3.0    25.0      7.0    94.0      5.3   1.733736   3.248264
# 714  37.0  2.0    15.0     11.0   108.0     11.8   5.250528   7.493472
# 715  46.0  1.0     7.0      6.0    41.0     23.4   0.585234   9.008766
# 716  26.0  4.0     1.0      5.0    92.0     13.0   6.506240   5.453760
# 717  33.0  1.0    16.0     12.0    46.0      8.1   2.399544   1.326456
# 718  43.0  1.0     8.0      0.0    32.0     19.0   1.234240   4.845760
# 719  49.0  2.0    14.0     26.0    63.0     15.8   0.935676   9.018324
# 720  44.0  1.0     2.0     15.0    22.0      9.6   1.091904   1.020096
# 721  32.0  1.0    12.0     10.0    33.0     11.2   0.794640   2.901360
# 722  38.0  1.0     5.0      4.0    20.0      1.5   0.091500   0.208500
# 723  52.0  1.0    33.0     23.0   139.0      5.6   2.288496   5.495504
# 724  35.0  1.0    10.0      3.0    24.0     21.3   1.083744   4.028256
# 725  33.0  4.0     4.0     12.0    22.0      5.5   0.566280   0.643720
# 713      NaN
# 714      NaN
# 715      NaN
# 716      NaN
# 717      NaN
# 718      NaN
# 719      NaN
# 720      NaN
# 721      NaN
# 722      NaN
# 723      NaN
# 724      NaN
# 725      NaN
# 726      NaN
# 727      NaN
# 728      NaN
# 729      NaN
# ..       ...
# 820      NaN
# 821      NaN
# 822      NaN
# 823      NaN
# 824      NaN
# 825      NaN
# 826      NaN
# 827      NaN
# 828      NaN
# 829      NaN
# 830      NaN
# 831      NaN
# 832      NaN
# 833      NaN
# 834      NaN
# 835      NaN
# 836      NaN
# 837      NaN
# 838      NaN
# 839      NaN
# 840      NaN
# 841      NaN
# 842      NaN
# 843      NaN
# 844      NaN
# 845      NaN
# 846      NaN
# 847      NaN
# 848      NaN
# 849      NaN
#
# [150 rows x 9 columns]

# %%
data=df[df.default.notnull()]

# %%
data
# Out:
#       age   ed  employ  address  income  debtinc   creddebt    othdebt  \
# 0    41.0  3.0    17.0     12.0   176.0      9.3  11.359392   5.008608
# 1    27.0  1.0    10.0      6.0    31.0     17.3   1.362202   4.000798
# 2    40.0  1.0    15.0     14.0    55.0      5.5   0.856075   2.168925
# 3    41.0  1.0    15.0     14.0   120.0      2.9   2.658720   0.821280
# 4    24.0  2.0     2.0      0.0    28.0     17.3   1.787436   3.056564
# 5    41.0  2.0     5.0      5.0    25.0     10.2   0.392700   2.157300
# 6    39.0  1.0    20.0      9.0    67.0     30.6   3.833874  16.668126
# 7    43.0  1.0    12.0     11.0    38.0      3.6   0.128592   1.239408
# 8    24.0  1.0     3.0      4.0    19.0     24.4   1.358348   3.277652
# 9    36.0  1.0     0.0     13.0    25.0     19.7   2.777700   2.147300
# 10   27.0  1.0     0.0      1.0    16.0      1.7   0.182512   0.089488
# 11   25.0  1.0     4.0      0.0    23.0      5.2   0.252356   0.943644
# 12   52.0  1.0    24.0     14.0    64.0     10.0   3.929600   2.470400
# 13   37.0  1.0     6.0      9.0    29.0     16.3   1.715901   3.011099
# 14   48.0  1.0    22.0     15.0   100.0      9.1   3.703700   5.396300
# 15   36.0  2.0     9.0      6.0    49.0      8.6   0.817516   3.396484
# 16   36.0  2.0    13.0      6.0    41.0     16.4   2.918216   3.805784
# 17   43.0  1.0    23.0     19.0    72.0      7.6   1.181952   4.290048
# 18   39.0  1.0     6.0      9.0    61.0      5.7   0.563274   2.913726
# 19   41.0  3.0     0.0     21.0    26.0      1.7   0.099008   0.342992
# 20   39.0  1.0    22.0      3.0    52.0      3.2   1.154816   0.509184
# 21   47.0  1.0    17.0     21.0    43.0      5.6   0.587552   1.820448
# 22   28.0  1.0     3.0      6.0    26.0     10.0   0.431600   2.168400
# 23   29.0  1.0     8.0      6.0    27.0      9.8   0.402192   2.243808
# 24   21.0  2.0     1.0      2.0    16.0     18.0   0.241920   2.638080
0
# 20       0.0
# 21       0.0
# 22       0.0
# 23       0.0
# 24       1.0
# 25       0.0
# 26       0.0
# 27       0.0
# 28       0.0
# 29       0.0
# ..       ...
# 670      0.0
# 671      0.0
# 672      0.0
# 673      1.0
# 674      0.0
# 675      0.0
# 676      0.0
# 677      1.0
# 678      0.0
# 679      0.0
# 680      1.0
# 681      1.0
# 682      0.0
# 683      0.0
# 684      0.0
# 685      1.0
# 686      0.0
# 687      1.0
# 688      0.0
# 689      0.0
# 690      0.0
# 691      0.0
# 692      1.0
# 693      0.0
# 694      0.0
# 695      1.0
# 696      0.0
# 697      0.0
# 698      0.0
# 699      0.0
#
# [700 rows x 9 columns]

# %%
y=data["default"]

# %%
x=data.drop(columns=["default"])

# %%
x.columns
# Out:
# Index(['age', 'ed', 'employ', 'address', 'income', 'debtinc', 'creddebt',
#        'othdebt'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression()
logisticRegr.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = logisticRegr.predict(x_train)

# %%
pred_y=pd.DataFrame(predictions, y_train)

# %%
pred_y.to_csv("Pred_actua.csv")

# %%
#Use score method to get accuracy of model
score = logisticRegr.score(x_train, y_train)
print(score)
# Out:
# 0.819047619047619

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
cm = metrics.confusion_matrix(y_train, predictions) # metrics.confusion_matrix(Actual, predicted)
print(cm)
# Out:
# [[354  32]
#  [ 63  76]]

# %%
accuracy_score(y_train, predictions)
# Out:
# 0.819047619047619

# %%
print(classification_report(y_train, predictions))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.85      0.92      0.88       386
#         1.0       0.70      0.55      0.62       139
#
# avg / total       0.81      0.82      0.81       525

# %%
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);

# %%
#results = confusion_matrix(actual, predicted)
#predictions

# %%
y_p=logisticRegr.predict_proba(x_train)

# %%
prod_prob=pd.DataFrame(y_p)

# %%
pred_y=pd.DataFrame(predictions)

# %%
x_train.to_csv("Train.csv")
pred_y.to_csv("pred_y.csv")
prod_prob.to_csv("prod_prob.csv")

# %%
y_train.to_csv("Actual_y.csv")

# %%
probs=y_p[:,1]

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr, tpr)
plt.show()

# %%
from sklearn.metrics import roc_auc_score

# calculate log loss
AUC = roc_auc_score(y_train, probs)
AUC
# Out:
# 0.8620606105788944

# %%
#An AUC score is a measure of the likelihood that the model that produced the
#predictions will rank a randomly chosen positive example above a randomly chosen negative example.
#Specifically, that the probability will be higher for a real event (class=1) than a real non-event 
#(class=0).
#Naive Prediction. A naive prediction under ROC AUC is any constant probability. 
#If the same probability is predicted for every example, there is no discrimination between positive
#and negative cases, therefore the model has no skill (AUC=0.5).

#Insensitivity to Class Imbalance. ROC AUC is a summary on the models ability to correctly 
#discriminate a single example across different thresholds. As such, it is unconcerned with the
#base likelihood of each class.

# %%
#Accuracy = correct predictions / total number of data points
def func(x):
    if 0 < x <= 10:
        return 'xxx'
    elif 10 < x <= 50:
        return 'yyy'
    return 'zzz'

df['col2'] = df['col1'].apply(func)
